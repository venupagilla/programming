# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
load_dotenv()
model=ChatGroq(model="openai/gpt-oss-120b",streaming=True)

# %%
ques=input("Ask your query : ")
resp=model.stream(ques)
for chunk in resp:
    print(chunk.content,end="")
# Out:
# ## One‑Month Aptitude‑Boost Plan
# *(Designed for busy professionals or students who can devote ≈ 2 hours a day)*
#
# | Week | Focus | Daily Time Allocation | Key Activities | Resources |
# |------|-------|-----------------------|----------------|-----------|
# | **1** | **Foundations & Diagnostic** | 30 min review + 90 min practice | • Take a short diagnostic test (30 min)  <br>• Identify weak‑areas (quant, logical, verbal)  <br>• Review basic math formulas, number‑systems, and common logical patterns  <br>• Start a “Formula & Trick” notebook | • *Quantitative Aptitude for Competitive Exams* (R.S. Aggarwal) – Chapters 1‑4  <br>• Online: Khan Academy – “Arithmetic”  <br>• Apps: Magoosh Aptitude Flashcards |
# | **2** | **Quantitative Reasoning** | 30 min concept + 60 min problem‑solving + 30 min timed drills | • Master percentages, ratios, profit‑loss, time‑& work, probability  <br>• Practice 15‑20 mixed questions daily (focus on speed)  <br>• End‑of‑day 5‑minute “speed‑run” of 5 easy problems | • *Quantitative Aptitude* (R.S. Aggarwal) – Chapters 5‑12  <br>• Website: Indiabix – “Quantitative” practice set  <br>• Timer app (e.g., Toggl) for drill timing |
# | **3** | **Logical & Analytical Reasoning** | 30 min theory + 60 min puzzles + 30 min mock | • Study syllogisms, seating arrangements, puzzles, data‑interpretation, series  <br>• Solve 1‑2 full‑length logical sections (20‑25 min each)  <br>• Review every mistake and write the underlying pattern in your notebook | • *How to Prepare for Logical Reasoning* (R.S. Aggarwal)  <br>• Web: LSAT Logical Reasoning Basics (Free on Khan Academy)  <br>• App: Pocket Puzzle (daily brain teasers) |
# | **4** | **Verbal Ability + Full‑Length Tests** | 30 min vocab/reading + 60 min mixed practice + 30 min review | • Build vocab (10 new words/day, use them in sentences)  <br>• Practice reading‑comprehension, para‑jumbles, grammar (sentence correction)  <br>• Take two full‑length timed mock tests (one mid‑week, one at week‑end)  <br>• Analyse results, note recurring error types, update notebook | • *Word Power Made Easy* (Norman Lewis) – selected chapters  <br>• Website: Examveda – Verbal Reasoning practice  <br>• Mock test platforms: TCYonline, Oliveboard, or Mettl (free trial) |
#
# ---
#
# ### Detailed Daily Routine (≈ 2 hrs)
#
# | Time | Activity |
# |------|----------|
# | **0‑5 min** | Quick warm‑up: mental math or a short puzzle to “wake the brain”. |
# | **5‑35 min** | **Concept Review** – read a short theory chunk (1–2 pages) or watch a 5‑minute video. |
# | **35‑95 min** | **Targeted Practice** – solve 12‑20 problems from the day’s topic. Use a timer: 2 min per easy, 3 min per medium, 5 min per hard. |
# | **95‑115 min** | **Speed Drill** – pick 5 “quick‑fire” questions (easy level) and finish them in 5 min. |
# | **115‑120 min** | **Reflection** – mark wrong answers, write the reason in your notebook, and note the formula/trick used. |
#
# *If you have only 1 hour, cut the speed drill and reflection to 5 min each; the core practice remains unchanged.*
#
# ---
#
# ### Weekly Checklist
#
# | ✔️ | Goal |
# |---|------|
# | **Week 1** | Complete diagnostic; compile a personal “Formula & Trick” sheet (≈ 2 pages). |
# | **Week 2** | Finish all core quantitative topics; achieve ≤ 30 seconds per basic arithmetic problem. |
# | **Week 3** | Solve ≥ 150 logical‑reasoning questions; be able to spot the pattern within 10 seconds. |
# | **Week 4** | Finish two full‑length mocks; improve overall accuracy to ≥ 80 % and reduce total time by 10 % compared to first mock. |
#
# ---
#
# ### Tracking Progress
#
# 1. **Spreadsheet** – columns: *Date, Topic, #Questions, Correct, Time Spent, Errors*
#    - Compute weekly accuracy = (Correct ÷ #Questions) × 100.
# 2. **Error Log** – a separate sheet where each mistake is recorded with:
#    - Question ID, Type (e.g., “percentage”, “sitting arrangement”), Reason for mistake, Correct approach. Review this log every Sunday.
# 3. **Score Graph** – plot mock‑test scores (percentile or raw) to visualize improvement.
#
# ---
#
# ### Tips for Maximizing Retention
#
# | Tip | Why It Works |
# |-----|--------------|
# | **Active Recall** – after reading a concept, close the book and recite the formula or rule aloud. | Reinforces memory pathways. |
# | **Spaced Repetition** – review your formula sheet every 2 days, then weekly. | Prevents forgetting. |
# | **Teach‑Back** – explain a tricky problem to a friend or record yourself. | Deepens understanding. |
# | **Mind‑Body Breaks** – 5‑minute stretch or walk after each 45‑minute block. | Keeps focus sharp. |
# | **Simulate Test Conditions** – turn off phone, use a timer, sit at a desk. | Trains stamina and reduces exam‑day anxiety. |
#
# ---
#
# ### Optional “Fast‑Track” Resources (if you need extra practice)
#
# | Resource | Cost | What It Gives |
# |----------|------|---------------|
# | **Magoosh Aptitude Prep** | $79/year | Video lessons + 1,000+ practice Qs + analytics |
# | **GMAT Club Tests** | Free / $20 per test | Very tough quantitative & logical sets |
# | **Khan Academy “College Math”** | Free | In‑depth videos for algebra, probability, statistics |
# | **Quizlet “Aptitude Vocabulary”** | Free | Flashcards with spaced‑repetition algorithm |
#
# ---
#
# ## TL;DR – One‑Month Action Plan
#
# 1. **Day 1‑2** – Take a diagnostic, list weak spots, start a formula notebook.
# 2. **Days 3‑14** – Focus on quantitative basics; 2 hrs/day (concept + 15‑20 Qs + speed drill).
# 3. **Days 15‑21** – Switch to logical/analytical reasoning; same time split.
# 4. **Days 22‑28** – Build verbal vocab & reading; do two full‑length timed mocks (mid‑week & weekend).
# 5. **Days 29‑30** – Review error log, polish formulas, rest well before the real test.
#
# Stick to the schedule, record every mistake, and you’ll see a **10‑15 % boost in accuracy and a noticeable speed gain** by the end of the month. Good luck!
