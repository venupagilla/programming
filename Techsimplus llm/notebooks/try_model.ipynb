# %%
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage,AIMessage,SystemMessage
from dotenv import load_dotenv
load_dotenv()
model=ChatGroq(model="openai/gpt-oss-120b")
conv=[
    SystemMessage("You are a teacher"),
    HumanMessage("hi"),
    SystemMessage("hi student"),
    HumanMessage("what is algebra?")
]
resp=model.invoke(conv)

# %%
print(resp.content)
# Out:
# **Algebra** is a branch of mathematics that uses symbols—usually letters—to represent numbers and the relationships between them. While arithmetic deals with specific numbers (e.g., 2 + 3 = 5), algebra lets us work with **unknowns** and **general formulas**, making it possible to solve a wide variety of problems in a systematic way.
#
# ---
#
# ## Key Ideas
#
# | Concept | What It Means | Simple Example |
# |---------|----------------|----------------|
# | **Variable** | A symbol (like *x* or *y*) that stands for an unknown or a value that can change. | In *x + 3 = 7*, *x* is the variable. |
# | **Expression** | A combination of numbers, variables, and operations (addition, subtraction, multiplication, division, exponents). | *2x − 5* is an expression. |
# | **Equation** | A statement that two expressions are equal; solving it means finding the value(s) of the variable(s) that make the statement true. | *3x = 12* → *x = 4*. |
# | **Term** | A single part of an expression separated by + or –. | In *4a + 3b − 2*, the terms are *4a*, *3b*, and *‑2*. |
# | **Coefficient** | The number multiplying a variable. | In *7y*, the coefficient is 7. |
# | **Constant** | A fixed number that doesn’t change. | In *5x + 9*, the constant is 9. |
# | **Function** | A rule that assigns each input (often *x*) exactly one output (often *f(x)*). | *f(x) = 2x + 1* is a linear function. |
#
# ---
#
# ## Why Algebra Matters
#
# 1. **Generalization** – Instead of solving a single numeric problem, algebra gives a formula that works for many cases.
# 2. **Problem‑solving** – Many real‑world situations (e.g., calculating distance, budgeting, physics formulas) can be modeled with algebraic equations.
# 3. **Foundation for advanced math** – Topics like calculus, statistics, and linear algebra build directly on algebraic concepts.
#
# ---
#
# ## A Simple Walk‑through
#
# **Problem:** A rectangle’s length is 3 cm more than its width. If the area is 70 cm², what are the dimensions?
#
# 1. **Introduce a variable** for the unknown quantity.
#    Let the width be *w* (cm).
#    Then the length is *w + 3* cm.
#
# 2. **Write an equation** using the known relationship (area = length × width).
#    \[
#    w \times (w + 3) = 70
#    \]
#
# 3. **Expand and simplify** (this is called forming a quadratic equation).
#    \[
#    w^2 + 3w - 70 = 0
#    \]
#
# 4. **Solve** the quadratic—factor, complete the square, or use the quadratic formula.
#    Factoring: \((w + 10)(w - 7) = 0\) → *w = 7* (the negative solution *w = –10* isn’t physically meaningful here).
#
# 5. **Find the other dimension.**
#    Length = *w + 3* = 7 + 3 = **10 cm**.
#
# **Answer:** Width = 7 cm, Length = 10 cm.
#
# ---
#
# ## Quick Tips for Getting Comfortable with Algebra
#
# | Tip | How to Apply |
# |-----|--------------|
# | **Practice “undoing” operations** (inverse operations). | To isolate *x* in *2x + 5 = 13*, subtract 5, then divide by 2. |
# | **Keep equations balanced** – whatever you do to one side, do to the other. | If you add 4 to the left side, add 4 to the right side. |
# | **Check your work** by plugging the solution back into the original equation. | For *x = 4* in *3x − 2 = 10*, compute 3·4 − 2 = 10 (true). |
# | **Learn common patterns** (difference of squares, perfect‑square trinomials, factoring). | Recognizing *a² − b² = (a − b)(a + b)* speeds up solving. |
# | **Use visual aids** (number lines, algebra tiles) when you’re first learning. | They help you see how terms combine or cancel. |
#
# ---
#
# ### A Mini‑Exercise for You
#
# Solve for *x*:
#
# \[
# 5x - 7 = 2x + 8
# \]
#
# *Steps to try:*
# 1. Subtract *2x* from both sides.
# 2. Add 7 to both sides.
# 3. Divide by the coefficient of *x*.
#
# Give it a go, and let me know what answer you get! If you get stuck, just ask and I’ll walk you through each step.
