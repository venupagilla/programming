# %%
from langchain_ollama import ChatOllama

# %%
model=ChatOllama(model="gemma3:270m")

# %%
resp=model.invoke("What do you mean by mammals")

# %%
print(resp.content)
# Out:
# Mammals are animals that have mammary glands, which are responsible for producing milk to feed their young. They also have hair, fur, and other physical characteristics that are characteristic of mammals.
