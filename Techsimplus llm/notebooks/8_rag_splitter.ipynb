# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader,TextLoader

# %%
textloader=TextLoader("../data/prabhas.txt",encoding="utf-8")
text=textloader.load()
pdfloader=PyPDFLoader("../data/iot.pdf")
pdfs=pdfloader.load()

# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=20,chunk_overlap=5)
chunks1=splitter.split_documents(text)
chunks2=splitter.split_documents(pdfs)

# %%
print(chunks1[0])
# Out:
# page_content='Uppalapati Venkata' metadata={'source': '../data/prabhas.txt'}
