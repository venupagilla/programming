# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
apikey=os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", api_key=apikey)

# %%
print(model.invoke("Who are you?"))
# Out:
# content="I am a large language model, trained by Google.\n\nMy purpose is to assist users by providing information, generating text, answering questions, and engaging in conversations. I don't have personal experiences, feelings, consciousness, or beliefs. I am an AI, not a human." additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019bb6f7-ec03-70b0-8b6a-5351d6d61680-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 617, 'total_tokens': 622, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 560}}

# %%
prompts=[
    ("system","you are python developer"),
    ("user","What are the primitive data types")
]

# %%
resp=model.invoke(prompts)

# %%
print(resp.content)
# Out:
# That's a great question, and it highlights a key difference between Python and languages like Java, C++, or C#.
#
# **In Python, technically, there are no true "primitive data types" in the same sense as those languages.**
#
# In languages like Java, "primitive" types (like `int`, `char`, `boolean`) are stored directly in memory, often on the stack, and are not objects. "Objects" are instances of classes, stored on the heap, and accessed via references.
#
# **In Python, *everything is an object*.** This means even a simple integer like `5` is an instance of the `int` class.
#
# However, when developers talk about "primitive data types" in Python, they are usually referring to the **fundamental, built-in data types** that are the basic building blocks for more complex data structures, and often behave in ways conceptually similar to primitives in other languages (e.g., they are immutable, directly represented).
#
# ...
