# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain.agents import create_agent
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import MemorySaver
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
search=GoogleSerperAPIWrapper()
llm=ChatGroq(model="openai/gpt-oss-120b")
agent=create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="you are an agent who can search anything on google",
    checkpointer=MemorySaver()
)

# %%
ques=input("Enter you question : ")
response=agent.invoke(
    {"messages":[{"role":"user","content":ques}]},
    {"configurable":{"thread_id":"1"}},
    )
print(response["messages"][-1].content)
# Out:
# **Anjali Tendulkar (née Mehta)**
#
# - **Full name:** Anjali Tendulkar (born Anjali Mehta)
# - **Date of birth:** 10 November 1967 (making her 58 years old as of February 2026)
# - **Profession:** Businesswoman and former model; she runs a boutique called **‘Anjali Boutique’** in Mumbai and has been involved in various charitable activities, especially those related to education and health.
#
# ### How they met & marriage
# - Anjali and Sachin first met in the early 1990s through a mutual friend.
# - They were officially introduced by a family friend, and their relationship grew quickly.
# - The couple married on **24 February 1995** in a private ceremony at the **Madhav Sagar Temple** in Mumbai, attended by close family and friends.
#
# ### Family
# - **Children:**
#   1. **Sara Tendulkar** – born 1 October 1997, a professional photographer and entrepreneur.
#   2. **Arjun Tendulkar** – born 24 September 1999, a left‑arm fast‑bowling all‑rounder who has played domestic cricket for Mumbai and has been part of India’s Under‑19 squads.
#
# ### Public profile
# - Anjali maintains a relatively low‑key public presence compared with many celebrity spouses, preferring to focus on her family and philanthropic work.
# - She is often seen supporting Sachin at cricket events, award ceremonies, and charitable functions.
# - The couple is regarded as one of India’s most enduring and respected celebrity partnerships.

# %%
print(response["messages"][-1].content)
# Out:
# **Anjali Tendulkar (née Mehta)**
#
# - **Full name:** Anjali Tendulkar (born Anjali Mehta)
# - **Date of birth:** 10 November 1967 (making her 58 years old as of February 2026)
# - **Profession:** Businesswoman and former model; she runs a boutique called **‘Anjali Boutique’** in Mumbai and has been involved in various charitable activities, especially those related to education and health.
#
# ### How they met & marriage
# - Anjali and Sachin first met in the early 1990s through a mutual friend.
# - They were officially introduced by a family friend, and their relationship grew quickly.
# - The couple married on **24 February 1995** in a private ceremony at the **Madhav Sagar Temple** in Mumbai, attended by close family and friends.
#
# ### Family
# - **Children:**
#   1. **Sara Tendulkar** – born 1 October 1997, a professional photographer and entrepreneur.
#   2. **Arjun Tendulkar** – born 24 September 1999, a left‑arm fast‑bowling all‑rounder who has played domestic cricket for Mumbai and has been part of India’s Under‑19 squads.
#
# ### Public profile
# - Anjali maintains a relatively low‑key public presence compared with many celebrity spouses, preferring to focus on her family and philanthropic work.
# - She is often seen supporting Sachin at cricket events, award ceremonies, and charitable functions.
# - The couple is regarded as one of India’s most enduring and respected celebrity partnerships.
